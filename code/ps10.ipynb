# %%
# %matplotlib inline
# %run convenience.ipynb
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

np.set_printoptions(precision=2,suppress=True) # numpy output options

pi=np.pi
j=1j

# %% [markdown]
# ### System characterization with Bode plot, step response and pole-zero map

# %%
# 3A
combinedplot(signal.lti([1,0],[1,1]))
# Out:
# /home/james/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# It is a linear system that act as a high pass filter. There are one poles and one zero both on the real axis.

# %%
# 3B
combinedplot(signal.lti([1,0],[1,100, 1]))

# %% [markdown]
# This is a second order system that act as a band pass filter. The pole and zero are both on the real axis. The step response slowly die off.

# %%
# 3C
combinedplot(signal.lti([1,0],[1,1, 1]))

# %% [markdown]
# Another second order system. The step response shows a damped oscillation. Two imaginary poles and one real zero. It seems like the imaginary part causes the oscillation.

# %%
# 3D
combinedplot(signal.lti([1,0],[1,.1, 1]))

# %% [markdown]
# A second order systme that acts like 3C with an oscillation that slowly dies out. The poles are closer to the zero on the imaginary axis which seems to cause the stronger oscillation .

# %%
# 3E
combinedplot(signal.lti([1,-0.01, 1],[1,.01, 1]))

# %% [markdown]
# A second order systme that doesnt kill signals and shifts the phase. There seem to be a slight oscillation that dies out pretty quickly.

# %%
# 3F
combinedplot(signal.lti([1,0.1, 1],[1,.11, 1]))

# %% [markdown]
# A second order systme that kills a specific frequency. There is a pair of imaginary pole and a pair of imaginary zeros.

# %%
# 4A
combinedplot(signal.lti([1],[1,-.01, 1]))

# %% [markdown]
# It has two imaginary poles. The step response shows an unstable oscillation that increase in amplitude.

# %%
# 4B
Kp = 1
combinedplot(signal.lti([Kp],[1,-.01, 1+Kp]))

# %% [markdown]
# The proportional control is not able to stabilize the system.

# %%
# 4C
Ki = .1
combinedplot(signal.lti([Ki],[1,-.01, 1, Ki]))
# second order two imaginary poles the system oscillates and gets bigger

# %% [markdown]
# This is a second order that act as a band pass filter. The pole and zero are both on the real axis. The step response slowly die off.

# %%
# 4D
Kd = 1
combinedplot(signal.lti([Kd],[1,-.01 + Kd, 1]))

# %% [markdown]
# The derivative control is able to stablize the system. The poles are moved from the right of the imaginary axis to left and this seems to stablize the system.
